# %% [markdown]
# # Pandas Tutorial (Day-11)
#
# This notebook explains

# %% [markdown]
# #### 1- How to Inatall Libraries

# %%
# pip install pandas
# pip install numpy

# %% [markdown]
# ### 2- Import libraies

# %%
import pandas as pd
import numpy as np

# %%
# Object creation
s = pd.Series([1,2,3,4,5,6,np.nan,7])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    NaN
# 7    7.0
# dtype: float64

# %%
dates = pd.date_range('20240201', '20240301' ,freq='D')
print(dates)
len(dates)
# Out:
# DatetimeIndex(['2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04',
#                '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08',
#                '2024-02-09', '2024-02-10', '2024-02-11', '2024-02-12',
#                '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16',
#                '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20',
#                '2024-02-21', '2024-02-22', '2024-02-23', '2024-02-24',
#                '2024-02-25', '2024-02-26', '2024-02-27', '2024-02-28',
#                '2024-02-29', '2024-03-01'],
#               dtype='datetime64[ns]', freq='D')
# 30

# %%
dates = pd.date_range('20240201', '20240229' ,freq='D')
df = pd.DataFrame(np.random.randn(29,4),index=dates, columns=list("EFGH"))
print(df)
# Out:
#                    E         F         G         H
# 2024-02-01  0.944628 -0.746963  0.606073  1.623237
# 2024-02-02 -0.612834 -0.090527  1.010562  2.480776
# 2024-02-03  1.648741  0.458099 -0.009517  0.760697
# 2024-02-04  0.306806  0.667856 -0.615155 -1.002388
# 2024-02-05 -0.406895 -0.201415  0.229159  0.904020
# 2024-02-06 -1.211054  1.057763 -0.864059 -0.526508
# 2024-02-07  0.431163 -0.785138  1.112061  0.319389
# 2024-02-08  0.458353  0.368758  0.905598 -0.153453
# 2024-02-09 -0.955667 -0.164912  0.180257  0.446320
# 2024-02-10 -0.668229  1.111110  1.331655  0.323329
# 2024-02-11  0.392046 -1.465721  0.331282  0.268361
# 2024-02-12  0.098339 -0.417744 -0.381257 -0.553202
# 2024-02-13  0.540560  0.206847  0.784627  0.934535
# 2024-02-14 -0.343800 -0.308201  1.242615  0.824659
# 2024-02-15 -0.821339  0.599889 -1.025711  0.000574
# 2024-02-16 -1.123194 -1.033781  0.100341  0.441496
# 2024-02-17 -0.701318 -0.117960 -0.610483 -0.744904
# ...

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220203"),
        "C": pd.Series(1,index=list(range(4)), dtype="float32"),
        "D": np.array([3]*4, dtype="int32"),
        "E": pd.Categorical(["girl","Woman", "girl", "Woman"]),
        "F": "females"
    }
)
print(df2)
print(df2.dtypes)
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-02-03  1.0  3   girl  females
# 1  1.0 2022-02-03  1.0  3  Woman  females
# 2  1.0 2022-02-03  1.0  3   girl  females
# 3  1.0 2022-02-03  1.0  3  Woman  females
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
dates = pd.date_range('20240201', '20240229' ,freq='D')
df = pd.DataFrame(np.random.randn(29,4),index=dates, columns=list("EFGH"))
print(df.head(2))
print(df.tail(2))
print(df.index)
# Out:
#                    E         F         G         H
# 2024-02-01  1.553931  0.450749 -0.382651 -2.334866
# 2024-02-02  0.731664  0.047837 -0.748996  0.517475
#                    E         F         G         H
# 2024-02-28 -0.839831 -1.252885  0.275719 -1.113078
# 2024-02-29  0.362919 -0.044535 -0.096247  0.006876
# DatetimeIndex(['2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04',
#                '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08',
#                '2024-02-09', '2024-02-10', '2024-02-11', '2024-02-12',
#                '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16',
#                '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20',
#                '2024-02-21', '2024-02-22', '2024-02-23', '2024-02-24',
#                '2024-02-25', '2024-02-26', '2024-02-27', '2024-02-28',
#                '2024-02-29'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('20240201', '20240229' ,freq='D')
df = pd.DataFrame((np.random.randn(29,4)*100),index=dates, columns=list("EFGH"))
dfarray = df.to_numpy
print(dfarray())
# Out:
# [[ 3.41540455e+01  4.68654818e+01  2.52492730e+01  5.85806110e+01]
#  [-1.97614701e+02 -7.52491780e+01  1.09173159e+02 -1.48442006e+02]
#  [ 1.06578922e+02  6.08497480e+01  9.88787129e+01  6.73218775e+01]
#  [ 6.26209358e-01 -8.07644396e+01 -1.55945767e+02  4.27235707e+01]
#  [ 6.85830949e+01  8.00468600e+01 -7.46251947e+01 -1.21644235e+02]
#  [ 6.31826172e+01  9.27559732e+01 -4.66982787e+01  1.20790634e+02]
#  [-4.23446365e+01  2.45514252e+01  1.04506696e+02  8.45523331e+01]
#  [ 4.50423331e+01  1.48524267e+02 -7.08822443e+01 -3.46600352e+01]
#  [ 1.67485195e+01 -8.29920035e+01 -1.35401018e+02  5.75750550e+01]
#  [-8.28259047e+01  7.57526790e+01  3.67498839e+01 -6.25096296e+01]
#  [ 8.50567159e+01 -8.78639752e+01 -1.33126019e+02  5.81457618e+01]
#  [ 1.25368998e+02  3.26305576e+02  4.26361938e+01 -4.40224455e+01]
#  [ 2.22425277e+01 -1.45693104e+02 -3.57364446e+01  1.12353856e+02]
#  [-9.73004082e+01 -5.71125697e+01 -2.16692262e+01  1.24102566e+01]
# ...

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-02-03 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-02-03 00:00:00'), 1.0, 3, 'Woman',
#         'females'],
#        [1.0, Timestamp('2022-02-03 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-02-03 00:00:00'), 1.0, 3, 'Woman',
#         'females']], dtype=object)

# %%
df.describe()
# Out:
#                 E           F           G           H
# count   29.000000   29.000000   29.000000   29.000000
# mean    12.892336  -12.690629  -12.415540   -6.547439
# std    102.537421  121.208342   93.242140  114.287914
# min   -251.090504 -231.934987 -155.945767 -242.706528
# 25%    -31.839871  -87.863975  -79.552652  -71.078948
# 50%     25.793461  -57.112570  -32.360190    9.057819
# 75%     68.583095   75.752679   42.636194   61.316541
# max    198.019010  326.305576  189.203332  267.391309

# %%
# To Transpose Data
print(df2)
df2.T
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-02-03  1.0  3   girl  females
# 1  1.0 2022-02-03  1.0  3  Woman  females
# 2  1.0 2022-02-03  1.0  3   girl  females
# 3  1.0 2022-02-03  1.0  3  Woman  females
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2022-02-03 00:00:00  2022-02-03 00:00:00  2022-02-03 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 girl                Woman                 girl
# F              females              females              females
#
#                      3
# A                  1.0
# B  2022-02-03 00:00:00
# C                  1.0
# D                    3
# E                Woman
# F              females

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('
# 2024-02-08     48.029195
# 2024-02-09    131.256685
# 2024-02-10   -100.339450
# 2024-02-11     45.589826
# 2024-02-12     56.856603
# 2024-02-13    -62.090831
# 2024-02-14      7.813869
# 2024-02-15     55.680854
# 2024-02-16     78.606954
# 2024-02-17    -55.282746
# 2024-02-18     36.986920
# 2024-02-19     -9.161185
# 2024-02-20      5.640066
# 2024-02-21   -134.351195
# 2024-02-22    -85.887888
# 2024-02-23     -0.433275
# 2024-02-24   -101.260790
# 2024-02-25    138.448986
# 2024-02-26    -29.163994
# 2024-02-27     85.935609
# 2024-02-28     43.029307
# 2024-02-29     19.201662
# Freq: D, Name: F, dtype: float64

# %%
# Row wise selection
df[10:12]
# Out:
#                      E          F          G           H
# 2024-02-11 -201.307170  45.589826  89.532680 -202.034682
# 2024-02-12   29.097141  56.856603  82.779835 -153.151549

# %%
df.loc[dates[0]]
# Out:
# E     67.677945
# F   -106.398823
# G     -1.283135
# H   -153.954645
# Name: 2024-02-01 00:00:00, dtype: float64

# %%
df.loc[dates[20]]
# Out:
# E     64.585223
# F   -134.351195
# G    -89.308465
# H    -86.888457
# Name: 2024-02-21 00:00:00, dtype: float64

# %%
df.loc[dates[11:20:2]]
# Out:
#                      E          F           G           H
# 2024-02-12   29.097141  56.856603   82.779835 -153.151549
# 2024-02-14  112.180910   7.813869  -22.242082 -144.746411
# 2024-02-16 -180.203673  78.606954  110.854484  -56.969845
# 2024-02-18   34.603721  36.986920 -101.555164  165.373588
# 2024-02-20 -103.696557   5.640066  -85.098641 -186.387482

# %%
df.loc[:, ['E', 'F']]
# Out:
#                      E           F
# 2024-02-01   67.677945 -106.398823
# 2024-02-02 -201.067076  280.391568
# 2024-02-03    3.011087 -123.763823
# 2024-02-04   42.652784   14.887071
# 2024-02-05   92.430301   78.923473
# 2024-02-06   72.847125  126.363105
# 2024-02-07   11.036639  128.808386
# 2024-02-08  -54.385732   48.029195
# 2024-02-09 -108.175908  131.256685
# 2024-02-10 -130.474692 -100.339450
# 2024-02-11 -201.307170   45.589826
# 2024-02-12   29.097141   56.856603
# 2024-02-13   56.233057  -62.090831
# 2024-02-14  112.180910    7.813869
# 2024-02-15  -59.318077   55.680854
# 2024-02-16 -180.203673   78.606954
# 2024-02-17    2.496713  -55.282746
# 2024-02-18   34.603721   36.986920
# 2024-02-19   -1.971798   -9.161185
# 2024-02-20 -103.696557    5.640066
# 2024-02-21   64.585223 -134.351195
# 2024-02-22  -89.004926  -85.887888
# 2024-02-23  -37.310441   -0.433275
# 2024-02-24  -27.020037 -101.260790
# 2024-02-25   67.277870  138.448986
# 2024-02-26  -69.134307  -29.163994
# ...

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20240201', '20240229' ,freq='D')
df = pd.DataFrame((np.random.randn(29,4)*100),index=dates, columns=list("EFGH"))
df.loc['2024-02-01'::7, ['E', 'F']]
# Out:
#                      E           F
# 2024-02-01   41.622127   -2.351054
# 2024-02-08  -93.989047  258.011582
# 2024-02-15 -172.878426   15.651413
# 2024-02-22 -283.596308  111.943016
# 2024-02-29 -152.127186  -31.313077

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('